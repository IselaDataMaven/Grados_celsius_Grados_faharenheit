# %%
import pandas as pd

# %%
pip install scikit-learn

# %%
from sklearn.linear_model import LinearRegression

# %%
datos = pd.read_csv('celsius.csv')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Celsius      7 non-null      int64
#  1   Faharenheit  7 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 244.0 bytes

# %%
datos.head()
# Out:
#    Celsius  Faharenheit
# 0      -40         40.0
# 1      -10         14.0
# 2        0         32.0
# 3        8         46.4
# 4       15         59.0

# %%
import seaborn as sb
import pandas as pd

# %%
data = {
    "celsius": [0,10, 20, 30, 40],
    "fahrenheit": [32, 50, 68, 86, 104]
}

datos = pd.DataFrame(data)

# %%
print(datos.head())
# Out:
#    celsius  fahrenheit
# 0        0          32
# 1       10          50
# 2       20          68
# 3       30          86
# 4       40         104

# %%
sb.scatterplot(x="celsius", y="fahrenheit", data=datos)
# Out:
# <Axes: xlabel='celsius', ylabel='fahrenheit'>

# %%
sb.scatterplot(x="celsius", y="fahrenheit", data=datos, hue="fahrenheit", palette = "coolwarm")
# Out:
# <Axes: xlabel='celsius', ylabel='fahrenheit'>

# %%
from sklearn.linear_model import LinearRegression

# %%
# !pip install scikit-learn
from sklearn.linear_model import LinearRegression

# %%
x = datos[["celsius"]]  # suponiendo que "celsius" es una columna de tu DataFrame
print(type(x))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
x = datos[["celsius"]]
y = datos["fahrenheit"]

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
type(x.values)
# Out:
# numpy.ndarray

# %%
X.values.reshape(-1,1)
# Out:
# array([[ 0],
#        [10],
#        [20],
#        [30],
#        [40]])

# %%
X_procesada = X.values.reshape(-1,1)
y_procesada = y.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()  # 👈 Aquí defines el modelo
modelo.fit(X_procesada, y_procesada)
# Out:
# LinearRegression()

# %%
import numpy as np

# %%
modelo = LinearRegression()
modelo.fit(X_procesada, y_procesada)
# Out:
# LinearRegression()

# %%
import numpy as np

nueva_prediccion = modelo.predict(np.array([[6], [7], [8]]))
print("Predicted values for x = 6, 7, 8:", nueva_prediccion)
# Out:
# Predicted values for x = 6, 7, 8: [[42.8]
#  [44.6]
#  [46.4]]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_nuevos = np.array([[6], [7], [8]])
y_nuevos = modelo.predict(x_nuevos)

# %%
# Graficar los datos originales
plt.scatter(X, y, color='blue', label='Datos originales')

# Línea de regresión del modelo
plt.plot(X, modelo.predict(X), color='red', label='Línea del modelo')

# Graficar las nuevas predicciones
plt.scatter(x_nuevos, y_nuevos, color='green', label='Nuevas predicciones', marker='X', s=100)

# Añadir etiquetas y leyenda
plt.title('Regresión lineal: Celsius vs Fahrenheit')
plt.xlabel('Celsius')
plt.ylabel('Fahrenheit')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
modelo.predict([[123]])
# Out:
# array([[253.4]])

# %%
modelo.score(X_procesada, y_procesada)
# Out:
# 1.0

# %%
celsius = 500
prediccion=modelo.predict([[celsius]])
print(f"{celsius}grados celsius son {prediccion}frados faharenheit")
# Out:
# 500grados celsius son [[932.]]frados faharenheit
